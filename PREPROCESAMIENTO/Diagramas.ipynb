# %%
import pandas as pf

# %%
df=pf.read_csv("homicidios_clean.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76467 entries, 0 to 76466
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DEPARTAMENTO  76467 non-null  object
#  1   MUNICIPIO     76467 non-null  object
#  2   ARMAS_MEDIOS  76467 non-null  object
#  3   FECHA_HECHO   76467 non-null  object
#  4   GENERO        76467 non-null  object
#  5   GRUPO_ETARIO  76467 non-null  object
#  6   CANTIDAD      76467 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 4.1+ MB

# %%
df.shape
# Out:
# (76467, 7)

# %%
df.CANTIDAD.value_counts().sort_index()
# Out:
# CANTIDAD
# 1     69757
# 2      5673
# 3       768
# 4       182
# 5        48
# 6        14
# 7        12
# 8         5
# 9         1
# 10        3
# 11        2
# 16        2
# Name: count, dtype: int64

# %%
# A histogram is a graph showing frequency distributions.
# aio = All In One

# Import the necessary libraries 
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# %%
# Get the number of deaths without repetitions
valores_cantidad = df.CANTIDAD.unique()

# Make sure all values ​​on the X axis are visible
plt.xticks(valores_cantidad)

# Function to format values ​​with thousands separators
formatter = FuncFormatter(lambda x, pos: f'{int(x):,}'.replace(',', '.'))

# Format the Y axis
plt.gca().yaxis.set_major_formatter(formatter)

# Add tags and title
plt.title('Histograma de CANTIDAD de Homicidios')
plt.xlabel('Cantidad de homicidios')
plt.ylabel('Frecuencia')

# Filter to exclude rows
# df = df[~df.CANTIDAD.isin([1,2])]
# df = df[df.GENERO.isin(['MASCULINO'])]

# Create a histogram with CANTIDAD column
n, bins, patches = plt.hist(df.CANTIDAD, color="gray")

# Add frequency labels above each bar, in thousands format
for i in range(len(n)):
    plt.text(bins[i] + 0.5, n[i] + 0.1, f'{int(n[i]):,}'.replace(',', '.'), ha='center', va='bottom', fontsize=10)

# Display the histogram
plt.show()

# %%
# Get the number of deaths without repetitions
valores_cantidad = df.CANTIDAD.unique()

# Make sure all values ​​on the X axis are visible
plt.xticks(valores_cantidad)

# Function to format values ​​with thousands separators
formatter = FuncFormatter(lambda x, pos: f'{int(x):,}'.replace(',', '.'))

# Format the Y axis
plt.gca().yaxis.set_major_formatter(formatter)

# Add tags and title
plt.title('Histograma de CANTIDAD de Homicidios')
plt.xlabel('Cantidad de homicidios')
plt.ylabel('Frecuencia')

# Filter to exclude rows
#df = df[~df.CANTIDAD.isin([1,2])]
df = df[df.GENERO.isin(['MASCULINO'])]

# Create a histogram with CANTIDAD column
n, bins, patches = plt.hist(df.CANTIDAD, color="blue")

# Add frequency labels above each bar, in thousands format
for i in range(len(n)):
    plt.text(bins[i] + 0.5, n[i] + 0.1, f'{int(n[i]):,}'.replace(',', '.'), ha='center', va='bottom', fontsize=10)

# Display the histogram
plt.show()

# %%
# Get the number of deaths without repetitions
valores_cantidad = df.CANTIDAD.unique()

# Make sure all values ​​on the X axis are visible
plt.xticks(valores_cantidad)

# Function to format values ​​with thousands separators
formatter = FuncFormatter(lambda x, pos: f'{int(x):,}'.replace(',', '.'))

# Format the Y axis
plt.gca().yaxis.set_major_formatter(formatter)

# Add tags and title
plt.title('Histograma de CANTIDAD de Homicidios')
plt.xlabel('Cantidad de homicidios')
plt.ylabel('Frecuencia')

# Filter to exclude rows
#df = df[~df.CANTIDAD.isin([1,2])]
df = df[df.GENERO.isin(['FEMENINO'])]

# Create a histogram with CANTIDAD column
n, bins, patches = plt.hist(df.CANTIDAD, color="gray")

# Add frequency labels above each bar, in thousands format
for i in range(len(n)):
    plt.text(bins[i] + 0.5, n[i] + 0.1, f'{int(n[i]):,}'.replace(',', '.'), ha='center', va='bottom', fontsize=10)

# Display the histogram
plt.show()
